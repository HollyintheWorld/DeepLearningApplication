# %% [markdown]
# 4. 3번과 동일하지만 dense layer만 사용한 신경만으로 회귀를 수행하라.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("C:/dataset/diabetes.csv")

df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X=df.drop('Outcome',axis=1)
X=X.drop('BMI',axis=1)
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y=df['BMI']
y.value_counts()
# Out:
# 32.0    13
# 31.6    12
# 31.2    12
# 0.0     11
# 32.4    10
#         ..
# 36.7     1
# 41.8     1
# 42.6     1
# 42.8     1
# 46.3     1
# Name: BMI, Length: 248, dtype: int64
# 32.0    13
# 31.6    12
# 31.2    12
# 0.0     11
# 32.4    10
#         ..
# 36.7     1
# 41.8     1
# 42.6     1
# 42.8     1
# 46.3     1
# Name: BMI, Length: 248, dtype: int64

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6      148             72             35        0
# 1              1       85             66             29        0
# 2              8      183             64              0        0
# 3              1       89             66             23       94
# 4              0      137             40             35      168
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48      180
# 764            2      122             70             27        0
# 765            5      121             72             23      112
# 766            1      126             60              0        0
# 767            1       93             70             31        0
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 7 columns]
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6      148             72             35        0
# 1              1       85             66             29        0
# 2              8      183             64              0        0
# 3              1       89             66             23       94
# 4              0      137             40             35      168
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48      180
# 764            2      122             70             27        0
# 765            5      121             72             23      112
# 766            1      126             60              0        0
# 767            1       93             70             31        0
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 7 columns]

# %%
#딥러닝 입력을 위해 Numpy로 변환
X = X.values

# %%
X
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.   ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.   ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.   ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ..., 112.   ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.   ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.   ,   0.315,  23.   ]])
# array([[  6.   , 148.   ,  72.   , ...,   0.   ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.   ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.   ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ..., 112.   ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.   ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.   ,   0.315,  23.   ]])

# %%
y
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (614, 7) (614,)
# (154, 7) (154,)
# (614, 7) (614,)
# (154, 7) (154,)

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(10,input_shape=(7,),activation='tanh'))
model.add(Dense(8,activation='tanh'))
model.add(Dense(6,activation='tanh'))
model.add(Dense(2,activation='softmax'))

model.add(Dense(1))
model.compile(Adam(lr=0.04),'mean_squared_error',metrics=['mean_squared_error', 'mae'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 10)                80
#
#  dense_6 (Dense)             (None, 8)                 88
#
#  dense_7 (Dense)             (None, 6)                 54
#
#  dense_8 (Dense)             (None, 2)                 14
#
#  dense_9 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 239
# Trainable params: 239
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/30
# 20/20 [==============================] - 0s 5ms/step - loss: 70.0208 - mean_squared_error: 70.0208 - mae: 6.2817 - val_loss: 61.6003 - val_mean_squared_error: 61.6003 - val_mae: 5.8402
# Epoch 2/30
# 20/20 [==============================] - 0s 3ms/step - loss: 68.4528 - mean_squared_error: 68.4528 - mae: 6.1838 - val_loss: 60.8251 - val_mean_squared_error: 60.8251 - val_mae: 5.8031
# Epoch 3/30
# 20/20 [==============================] - 0s 4ms/step - loss: 67.2081 - mean_squared_error: 67.2081 - mae: 6.1169 - val_loss: 60.2600 - val_mean_squared_error: 60.2600 - val_mae: 5.7727
# Epoch 4/30
# 20/20 [==============================] - 0s 4ms/step - loss: 66.1972 - mean_squared_error: 66.1972 - mae: 6.0654 - val_loss: 59.8801 - val_mean_squared_error: 59.8801 - val_mae: 5.7496
# Epoch 5/30
# 20/20 [==============================] - 0s 3ms/step - loss: 65.3947 - mean_squared_error: 65.3947 - mae: 6.0217 - val_loss: 59.5947 - val_mean_squared_error: 59.5947 - val_mae: 5.7370
# Epoch 6/30
# 20/20 [==============================] - 0s 4ms/step - loss: 64.7485 - mean_squared_error: 64.7485 - mae: 5.9849 - val_loss: 59.4513 - val_mean_squared_error: 59.4513 - val_mae: 5.7308
# Epoch 7/30
# 20/20 [==============================] - 0s 3ms/step - loss: 64.2699 - mean_squared_error: 64.2699 - mae: 5.9591 - val_loss: 59.3798 - val_mean_squared_error: 59.3798 - val_mae: 5.7288
# Epoch 8/30
# 20/20 [==============================] - 0s 4ms/step - loss: 63.8730 - mean_squared_error: 63.8730 - mae: 5.9385 - val_loss: 59.3547 - val_mean_squared_error: 59.3547 - val_mae: 5.7268
# Epoch 9/30
# 20/20 [==============================] - 0s 4ms/step - loss: 63.6013 - mean_squared_error: 63.6013 - mae: 5.9223 - val_loss: 59.3758 - val_mean_squared_error: 59.3758 - val_mae: 5.7271
# Epoch 10/30
# 20/20 [==============================] - 0s 4ms/step - loss: 63.3115 - mean_squared_error: 63.3115 - mae: 5.9104 - val_loss: 59.4085 - val_mean_squared_error: 59.4085 - val_mae: 5.7291
# Epoch 11/30
# 20/20 [==============================] - 0s 3ms/step - loss: 63.1479 - mean_squared_error: 63.1479 - mae: 5.9005 - val_loss: 59.4706 - val_mean_squared_error: 59.4706 - val_mae: 5.7319
# Epoch 12/30
# 20/20 [==============================] - 0s 4ms/step - loss: 63.0031 - mean_squared_error: 63.0031 - mae: 5.8909 - val_loss: 59.5547 - val_mean_squared_error: 59.5547 - val_mae: 5.7347
# Epoch 13/30
# 20/20 [==============================] - 0s 3ms/step - loss: 62.8727 - mean_squared_error: 62.8727 - mae: 5.8837 - val_loss: 59.6206 - val_mean_squared_error: 59.6206 - val_mae: 5.7379
# Epoch 14/30
# 20/20 [==============================] - 0s 6ms/step - loss: 62.8006 - mean_squared_error: 62.8006 - mae: 5.8800 - val_loss: 59.7287 - val_mean_squared_error: 59.7287 - val_mae: 5.7429
# Epoch 15/30
# 20/20 [==============================] - 1s 26ms/step - loss: 62.7097 - mean_squared_error: 62.7097 - mae: 5.8740 - val_loss: 59.8530 - val_mean_squared_error: 59.8530 - val_mae: 5.7478
# Epoch 16/30
# 20/20 [==============================] - 1s 25ms/step - loss: 62.6555 - mean_squared_error: 62.6555 - mae: 5.8703 - val_loss: 59.9532 - val_mean_squared_error: 59.9532 - val_mae: 5.7513
# Epoch 17/30
# 20/20 [==============================] - 0s 17ms/step - loss: 62.6182 - mean_squared_error: 62.6182 - mae: 5.8668 - val_loss: 60.0271 - val_mean_squared_error: 60.0271 - val_mae: 5.7537
# Epoch 18/30
# 20/20 [==============================] - 1s 27ms/step - loss: 62.5967 - mean_squared_error: 62.5967 - mae: 5.8652 - val_loss: 60.0613 - val_mean_squared_error: 60.0613 - val_mae: 5.7548
# Epoch 19/30
# 20/20 [==============================] - 0s 4ms/step - loss: 62.5881 - mean_squared_error: 62.5881 - mae: 5.8645 - val_loss: 60.1203 - val_mean_squared_error: 60.1203 - val_mae: 5.7571
# Epoch 20/30
# 20/20 [==============================] - 0s 3ms/step - loss: 62.5738 - mean_squared_error: 62.5738 - mae: 5.8640 - val_loss: 60.2174 - val_mean_squared_error: 60.2174 - val_mae: 5.7620
# Epoch 21/30
# 20/20 [==============================] - 1s 31ms/step - loss: 62.5601 - mean_squared_error: 62.5601 - mae: 5.8629 - val_loss: 60.2350 - val_mean_squared_error: 60.2350 - val_mae: 5.7629
# Epoch 22/30
# 20/20 [==============================] - 0s 4ms/step - loss: 62.5583 - mean_squared_error: 62.5583 - mae: 5.8627 - val_loss: 60.2444 - val_mean_squared_error: 60.2444 - val_mae: 5.7633
# Epoch 23/30
# 20/20 [==============================] - 0s 4ms/step - loss: 62.5473 - mean_squared_error: 62.5473 - mae: 5.8618 - val_loss: 60.3233 - val_mean_squared_error: 60.3233 - val_mae: 5.7670
# Epoch 24/30
# 20/20 [==============================] - 0s 4ms/step - loss: 62.5426 - mean_squared_error: 62.5426 - mae: 5.8617 - val_loss: 60.3663 - val_mean_squared_error: 60.3663 - val_mae: 5.7690
# Epoch 25/30
# 20/20 [==============================] - 0s 4ms/step - loss: 62.5470 - mean_squared_error: 62.5470 - mae: 5.8619 - val_loss: 60.4450 - val_mean_squared_error: 60.4450 - val_mae: 5.7725
# Epoch 26/30
# 20/20 [==============================] - 0s 12ms/step - loss: 62.5357 - mean_squared_error: 62.5357 - mae: 5.8608 - val_loss: 60.4801 - val_mean_squared_error: 60.4801 - val_mae: 5.7740
# Epoch 27/30
# 20/20 [==============================] - 0s 14ms/step - loss: 62.5426 - mean_squared_error: 62.5426 - mae: 5.8607 - val_loss: 60.5065 - val_mean_squared_error: 60.5065 - val_mae: 5.7751
# Epoch 28/30
# 20/20 [==============================] - 0s 15ms/step - loss: 62.5375 - mean_squared_error: 62.5375 - mae: 5.8610 - val_loss: 60.4797 - val_mean_squared_error: 60.4797 - val_mae: 5.7740
# Epoch 29/30
# 20/20 [==============================] - 0s 3ms/step - loss: 62.5349 - mean_squared_error: 62.5349 - mae: 5.8608 - val_loss: 60.5001 - val_mean_squared_error: 60.5001 - val_mae: 5.7749
# Epoch 30/30
# 20/20 [==============================] - 0s 3ms/step - loss: 62.5447 - mean_squared_error: 62.5447 - mae: 5.8606 - val_loss: 60.5931 - val_mean_squared_error: 60.5931 - val_mae: 5.7787
# 5/5 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error: ", mse)
# Out:
# Mean Squared Error:  60.5930874912371

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# MSE 기록이 모델 학습 중 기록되어야 합니다.
mse = model_history.history['mean_squared_error']
val_mse = model_history.history['val_mean_squared_error']
epochs = range(1, len(mse) + 1)

plt.figure(figsize=(12, 6))
plt.plot(epochs, mse, 'y', label='Training MSE')
plt.plot(epochs, val_mse, 'r', label='Validation MSE')
plt.title('Training and Validation MSE')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# 예측값과 실제값
y_pred = model.predict(X_test)

plt.figure(figsize=(12, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--', lw=2)
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()
# Out:
# 5/5 [==============================] - 0s 1ms/step
